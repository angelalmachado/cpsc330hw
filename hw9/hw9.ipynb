# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 9: Communication
#
# **Due date: See the [Calendar](https://htmlpreview.github.io/?https://github.com/UBC-CS/cpsc330/blob/master/docs/calendar.html)**

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Instructions
# <hr>
# rubric={points:2}
#
# Follow the [homework submission instructions](https://github.com/UBC-CS/cpsc330/blob/master/docs/homework_instructions.md).
#
# **You may work on this homework in a group and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 4.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 1: Communication
# <hr>

# %% [markdown]
# ### 1.1 Blog post
# rubric={points:23}
#
# Write up your analysis from hw5 or any other assignment or your side project on machine learning in a "blog post" or report format. It's fine if you just write it here in this notebook. Alternatively, you can publish your blog post publicly and include a link here. (See exercise 4.3.) The target audience for your blog post is someone like yourself right before you took this course. They don't necessarily have ML knowledge, but they have a solid foundation in technical matters. The post should focus on explaining **your results and what you did** in a way that's understandable to such a person, **not** a lesson trying to teach someone about machine learning. Again: focus on the results and why they are interesting; avoid pedagogical content.
#
# Your post must include the following elements (not necessarily in this order):
#
# - Description of the problem/decision.
# - Description of the dataset (the raw data and/or some EDA).
# - Description of the model.
# - Description your results, both quantitatively and qualitatively. Make sure to refer to the original problem/decision.
# - A section on caveats, describing at least 3 reasons why your results might be incorrect, misleading, overconfident, or otherwise problematic. Make reference to your specific dataset, model, approach, etc. To check that your reasons are specific enough, make sure they would not make sense, if left unchanged, to most students' submissions; for example, do not just say "overfitting" without explaining why you might be worried about overfitting in your specific case.
# - At least 3 visualizations. These visualizations must be embedded/interwoven into the text, not pasted at the end. The text must refer directly to each visualization. For example "as shown below" or "the figure demonstrates" or "take a look at Figure 1", etc. It is **not** sufficient to put a visualization in without referring to it directly.
#
# A reasonable length for your entire post would be **800 words**. The maximum allowed is **1000 words**.

# %% [markdown]
# #### Example blog posts
#
# Here are some examples of applied ML blog posts that you may find useful as inspiration. The target audiences of these posts aren't necessarily the same as yours, and these posts are longer than yours, but they are well-structured and engaging. You are **not required to read these** posts as part of this assignment - they are here only as examples if you'd find that useful.
#
# From the UBC Master of Data Science blog, written by a past student:
#
# - https://ubc-mds.github.io/2019-07-26-predicting-customer-probabilities/
#
# This next one uses R instead of Python, but that might be good in a way, as you can see what it's like for a reader that doesn't understand the code itself (the target audience for your post here):
#
# - https://rpubs.com/RosieB/taylorswiftlyricanalysis
#
# Finally, here are a couple interviews with winners from Kaggle competitions. The format isn't quite the same as a blog post, but you might find them interesting/relevant:
#
# - https://medium.com/kaggle-blog/instacart-market-basket-analysis-feda2700cded
# - https://medium.com/kaggle-blog/winner-interview-with-shivam-bansal-data-science-for-good-challenge-city-of-los-angeles-3294c0ed1fb2

# %% [markdown]
# #### A note on plagiarism
#
# You may **NOT** include text or visualizations that were not written/created by you. If you are in any doubt as to what constitutes plagiarism, please just ask. For more information see the [UBC Academic Misconduct policies](http://www.calendar.ubc.ca/vancouver/index.cfm?tree=3,54,111,959). Please don't copy this from somewhere 🙏. If you can't do it.

# %%
from IPython.display import Image

# %% [markdown]
# ### Description of problem/decision

# %% [markdown]
# The main focus of homework 4 was to build a machine learning (ML) model that successfully predicts whether a tweet will go viral or not. Since this is a binary classification problem, we decided to use a classification model called logistic regression. More on this model will be described below.
#
# We trained our model on a dataset of Donald Trump's tweets, the content of which we represented using a bag of words representation. This type of representation is useful for representing raw text in a format understandable by an ML model. It involves tracking the presence or absence of a word in a text, ignoring syntax and word order.

# %% [markdown]
# ### Description of dataset (raw data/EDA)

# %% [markdown]
# ### Description of the model
# #### Preprocessing

# %% [markdown]
# #### Logistic regression

# %% [markdown]
# Our chosen predictive model for this project was **logistic regression**. This is a model used for binary classification problems, and it learns the weight each feature in the dataset has in the prediction and a bias value. The model then uses this information to make the decision of how to classify the new example we give it. In our project, the model will learn the weight different words have on making a tweet go viral or not.
#
# For our analysis, we first **split the data** into training and testing sets, assigning 60% of the data to the test set. The, we implemented the preprocessing steps described above (`CountVectorizer`) and ran the logistic regression model.
#
# In this step, we also evaluated the model using **cross-validation** by splitting the training data into multiple folds, training the model on different subsets, and evaluating its average performance. The CV score obtained was 0.895.

# %% [markdown]
# #### Hyperparameter optimization

# %% [markdown]
# The goal of this step is to tune the configuration settings of our model (i.e., its hyperparameters) to improve its predictive performance. In our project, we optimized both `CountVectorizer` and `LogisticRegression` hyperparameters.
#
# **Optimizing `max_features` of `CountVectorizer`**
#
# The `max_features` hyperparameter controls the number of words that should be used when building the vocabulary of the model. We tested a range of possible values, from 10 up to 100,000. As shown in the graph below, 10,000 appears to be the optimal choice since it yields the highest CV score whilst keeping the gap between training and CV score at a minimum.

# %%
Image("max_feat.png")

# %% [markdown]
# **Optimizing `C` of `LogisticRegression`**
#
# The `C` hyperparameter controls the regularization of the logistic regression model, which in turn dictates how well our model will generalize to unseen data. After testing a range of values, our chosen `C` was 0.1. The same criteria used above were applied here: as seen in the plot below, 0.1 leads to the highest CV score and smallest gap between training and CV scores.

# %%
Image("logreg.png")

# %% [markdown]
# ### Quantitative and qualitative description of results

# %% [markdown]
# #### Coefficients

# %% [markdown]
# As mentioned previously, `Logistic Regression` predicts based on a feature’s coefficient (or weight) and the bias value. A positive coefficient, here, depicts that the presence of that particular word would push this example to be classified as “viral”. A negative coefficient, here, depicts that the presence of that particular word would push this example to be classified as “not viral”. The first table below shows the top 5 words that more likely to make a tweet viral and the second table shows bottom 5 words that are less likely to make a tweet viral.

# %%
Image("top_five.png")

# %%
Image("bottom_five.png")

# %% [markdown]
# #### Probability Scores

# %% [markdown]
# Apart from acquiring hard predictions of whether a tweet is viral or not, we can also look at the model’s confidence in classifying a tweet as viral and not viral. For instance, at 0.999 the model was most confident classifying the following tweet as viral:
#
#     “There was No Collusion with Russia (except by the Democrats). When will this very expensive Witch Hunt Hoax ever end? So bad for our Country. Is the Special Counsel/Justice Department leaking my lawyers letters to the Fake News Media? Should be looking at Dems corruption instead?”
#
# Considering it contains “Democrats” which is the top word, we can see why. In the table below, we can see other examples and the model’s confidence in classifying them as non-viral or viral respectively.

# %%
Image("predict_probas.png")

# %% [markdown]
# #### Test scores

# %% [markdown]
# After running the final model on the test set, we acquired an accuracy of **0.891** which is quite similar to the cross-validation score of **0.895**. This indicated that the model was not overfit. Therefore, our model is doing well and is fairly generalizable.

# %% [markdown]
# ### Caveats

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 1.2 Effective communication technique
# rubric={points:4}
#
# Describe one effective communication technique that you used in your post, or an aspect of the post that you are particularly satisfied with. (Max 3 sentences.)

# %% [markdown]
# <br><br>

# %% [markdown]
# ### (optional, not for marks) 1.3
#
# Publish your blog post from 1.1 publicly using a tool like Hugo, or somewhere like medium.com, and paste a link here. Be sure to pick a tool in which code and code output look reasonable. This link could be a useful line on your resume!

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 2: Your takeaway from the course
# rubric={points:1}
#
# **Your tasks:**
#
# What is your biggest takeaway from this course?
#
# > Please write thoughtful answers. I'm looking forward to read your answers 🙂.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# **PLEASE READ BEFORE YOU SUBMIT:**
#
# When you are ready to submit your assignment do the following:
#
# 1. Run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order or not starting from "1" will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Upload the assignment using Gradescope's drag and drop tool. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 4. Make sure that the plots and output are rendered properly in your submitted file. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb so that the TAs can view your submission on Gradescope.

# %% [markdown]
# ### Congratulations 👏👏
#
# That's all for the assignments! Congratulations on finishing all homework assignments!

# %%
from IPython.display import Image

Image("eva-congrats.png")
